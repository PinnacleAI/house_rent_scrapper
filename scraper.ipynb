# %%
import re
import csv
import requests
import bs4
from typing import List
from bs4 import BeautifulSoup

import psycopg2 as pg

# %%
class Database(object):
    def __init__(self):
        self.__password = "Nkopuruk"
        self.__dbname = "postgres"
        self.__user = 'postgres'
        self.__connected_to_db = False
        self.__conn = None
        self.__cursor = None
        
    @property
    def database_status(self):
        return self.__connected_to_db
    
    @database_status.setter
    def database_status(self, value):
        self.__connected_to_db = value
        
    def setup_database_connection(self):
        try:
            self.__conn = pg.connect(database=self.__dbname, user=self.__user, 
                                      password=self.__password)
            self.database_status = True
        except pg.Error as error:
            print(error)
            print("Unable to connect to database")
            
    def get_connection(self):
        return self.__conn
            
    def query(self, query) -> List[tuple]:
        cursor = self.__conn.cursor()
        try:
            cursor.execute(query)
        except pg.Error as e:
            # print(e)
            self.__conn.rollback()
        else:
            self.__conn.commit()
            if cursor.description is not None:
                return cursor.fetchall()
            
    def close_connection(self):
        self.__conn.close()

# %%
class Content:
    def __init__(self, title, url, address, no_of_bedrooms,
                 no_of_bathrooms, no_of_toilets, agent_contact, price, 
                 description):
        self.title = title
        self.url = url
        self.address = address
        self.no_of_bedrooms = no_of_bedrooms
        self.no_of_bathrooms = no_of_bathrooms
        self.no_of_toilets = no_of_toilets
        self.agent_contact = agent_contact
        self.price = price
        self.description = description
        # self.type = building_type

    def print(self):
        print(f"URL listing:\t{self.url}")
        print(f"Address:\t{self.address}")
        print(f"No of bedrooms:\t {self.no_of_bedrooms}")
        print(f"No of bathrooms:\t {self.no_of_bathrooms}")
        print(f"No of toilets:\t{self.no_of_toilets}")
        print(f"Agent contact:\t{self.agent_contact}")
        print(f"Price: \t {self.price}")
        print(f"Description: \t {self.description}")
        # print(f"Building Type: \t {self.type}")

# %%
class Website:
    """Contains information about website structure"""

    def __init__(self, filename, url, search_url, result_listing, result_url, use_patterns,
                 absolute_url, title_tag, url_tag, address_tag, no_of_bedrooms_tag,
                 no_of_bathrooms_tag, no_of_toilets_tag, agent_contact_tag, price_tag, 
                 description_tag, get_parent):
        self.filename = filename
        self.url = url
        self.search_url = search_url
        self.result_listing = result_listing
        self.result_url = result_url
        self.use_patterns = use_patterns
        self.absolute_url = absolute_url

        self.title_tag = title_tag
        self.url_tag = url_tag

        self.address_tag = address_tag
        self.no_of_bedrooms_tag = no_of_bedrooms_tag
        self.no_of_bathrooms_tag = no_of_bathrooms_tag
        self.no_of_toilets_tag = no_of_toilets_tag
        self.agent_contact_tag = agent_contact_tag
        self.price_tag = price_tag
        self.description_tag = description_tag
        # self.type_tag = type_tag

        self.get_parent = get_parent

# %%
class Crawler:
    def __init__(self, site):
        self.site = site
        self.visited = set()
        self.content = []
        
        self.database = Database()
        self.database.setup_database_connection()

    def get_page(self, url) -> BeautifulSoup or None:
        """Using the url download the page link and convert to
        a Beautiful object"""
        try:
            req = requests.get(url)
        except requests.exceptions.RequestException:
            return None
        return BeautifulSoup(req.content, 'html5lib')

    def safe_get(self, page_obj, selector, pattern, parent=False, inner_page_link=None) -> bs4.ResultSet or str:
        """Retrieve the information from the page object using the selector"""
        
        # go deeper into the page using the provided link
        if selector['access_inner_page']:
            if inner_page_link is None:
                return
            absolute_link = f"{self.site.url}{inner_page_link}"
            page_obj = self.get_page(absolute_link)
            
        if page_obj is not None:
            if not pattern:
                child_obj = page_obj.select(selector['selector'])
                if parent:

                    child_obj = page_obj.select(selector['selector'])
                    # if the tag doesn't contain the element
                    if child_obj:
                        child_obj = child_obj[0]
                        child_obj = child_obj.parent
            else:
                child_obj = page_obj.find_all('a', href=re.compile(selector['selector']))
            if child_obj is not None and len(child_obj) > 0:
                return child_obj
        return ""

    def get_links(self, page_url, selector) -> List[str]:
        """Get the links needed to navigate to the next page"""
        links = []
        page = self.get_page(page_url)

        if page is not None:
            for tag in self.safe_get(page, selector, True):
                if 'href' in tag.attrs:
                    link = tag.attrs['href']
                    links.append(link)
        return links

    def parse(self, url) -> list or None:
        """Parse the page to remove and save the needed information"""
        bs = self.get_page(url)
        if bs is not None:
            contents = []

            housing_list = self.safe_get(bs, self.site.result_listing, self.site.use_patterns)
            
            if housing_list is not None:
                for house in housing_list:
                    title = self.safe_get(house, self.site.title_tag, self.site.use_patterns)
                    url = self.safe_get(house, self.site.url_tag, self.site.use_patterns)
                    address = self.safe_get(house, self.site.address_tag, self.site.use_patterns)

                    no_of_bedroom = self.safe_get(house, self.site.no_of_bedrooms_tag, self.site.use_patterns,
                                                  self.site.get_parent)
                    no_of_bathroom = self.safe_get(house, self.site.no_of_bathrooms_tag, self.site.use_patterns,
                                                   self.site.get_parent)
                    no_of_toilet = self.safe_get(house, self.site.no_of_toilets_tag, self.site.use_patterns,
                                                 self.site.get_parent)
                    agent_contact = self.safe_get(house, self.site.agent_contact_tag, self.site.use_patterns)
                    price = self.safe_get(house, self.site.price_tag, self.site.use_patterns)
                    description = self.safe_get(house, self.site.description_tag, self.site.use_patterns)
                    # building_type = self.safe_get(house, self.site.type_tag, self.site.use_patterns, inner_page_link=url[0].attrs['href'])

                    content = Content(title, url, address, no_of_bedroom,
                                      no_of_bathroom, no_of_toilet, agent_contact, price,
                                      description
                                      # building_type
                                      )
                    contents.append(content)
            return contents

    def clean_text(self, text) -> str:
        clean_text = re.sub("[,\n+]", ' ', text)

        return clean_text

    def save_content_to_file(self, contents) -> None:
        for info in contents:
            try:
                Title = self.clean_text(info.title[0].get_text())
            except:
                Title = ""

            try:
                URL = f"{self.site.url}{info.url[0].attrs['href']}"
            except:
                URL = ""

            try:
                Address = self.clean_text(info.address[0].get_text())
            except:
                Address = "0"

            try:
                if self.site.get_parent:
                    No_of_Bedrooms = self.clean_text(info.no_of_bedrooms.get_text())
                else:
                    No_of_Bedrooms = self.clean_text(info.no_of_bedrooms[0].get_text())
            except:
                No_of_Bedrooms = "0"

            try:
                if self.site.get_parent:
                    No_of_Bathrooms = self.clean_text(info.no_of_bathrooms.get_text())
                else:
                    No_of_Bathrooms = self.clean_text(info.no_of_bathrooms[0].get_text())
            except:
                No_of_Bathrooms = "0"

            try:
                if self.site.get_parent:
                    No_of_Toilets = self.clean_text(info.no_of_toilets.get_text())
                else:
                    No_of_Toilets = self.clean_text(info.no_of_toilets[0].get_text())
            except:
                No_of_Toilets = "0"

            try:
                Price = self.clean_text(info.price[0].get_text()).strip()[1:]
            except:
                Price = ""

            try:
                Agent_Contact = self.clean_text(info.agent_contact[0].get_text())
            except:
                Agent_Contact = ""
                
            try:
                Description = self.clean_text(info.description[0].get_text())
            except:
                Description = ""
            
            # try:
            #     Type = self.clean_text(info.type[4].get_text())
            # except:
            #     raise ""

            compile_info = [Title, URL, Address, No_of_Bedrooms,
                            No_of_Bathrooms, No_of_Toilets, Price, Agent_Contact]
            
            Title = Title.replace("'", "''")
            Address = Address.replace("'", "''")
            Agent_Contact = Agent_Contact.replace("'", "''")
            Price = Price.replace("'", "''")
            Description = Description.replace("'", "''")
            # Type = Type.replace("'", "''")
            
            query = fr"""INSERT INTO house_rent (title, url, address, no_of_bedrooms, no_of_bathrooms, no_of_toilets, agent_contact, price, description)
                VALUES ('{Title}', '{URL}', '{Address}', '{No_of_Bedrooms}', '{No_of_Bathrooms}', '{No_of_Toilets}', '{Agent_Contact}', '{Price}', '{Description}')
                        """
            
            self.database.query(query)
            
    def crawl(self) -> None:
        """Crawl through the websites and retrieving the necessary information"""
        print("Crawler started")

        content = self.parse(self.site.search_url)
        if content is not None and len(content) > 0:
            self.content.extend(content)
            self.save_content_to_file(content)

        links_to_visit = []
        links = self.get_links(self.site.search_url, self.site.result_url)

        if len(links) > 0:
            links_to_visit.extend(links)

        self.visited.add(self.site.search_url)

        for link in links_to_visit:
            if link in self.visited:
                continue
            else:
                if not self.site.absolute_url:
                    absolute_link = f"{self.site.url}{link}"
                else:
                    absolute_link = link

                # remove the needed information from the current page
                content = self.parse(absolute_link)

                try:
                    if content is not None or len(content) >= 0:
                        # add the link of the current page to the list of page
                        # already visited
                        self.visited.add(link)

                        # save the parsed content
                        # self.content.extend(content)

                        # get new links from the current page to add to the list
                        # of pages to be visited
                        links = self.get_links(absolute_link, self.site.result_url)
                        links_to_visit.extend(links)

                        self.save_content_to_file(content)
                        print("Done parsing {}".format(absolute_link))
                    else:
                        print("Problem reading from \t{}".format(link))
                except TypeError:
                    print(f"Have encounter an error at {link}")

# %%
def create_options_dict(selector, access_inner_page=False) -> dict:
    return {"selector": selector, 'access_inner_page': access_inner_page}

nigeria_property = {
    "filename": "nigeria_property.csv",
    'url': "https://nigeriapropertycentre.com",
    'search_url': "https://nigeriapropertycentre.com/for-rent",
    "result_listing": create_options_dict('div[itemtype*=ListItem]'),
    "result_url": create_options_dict("/for-rent\?.*"),
    "use_patterns": False,
    "absolute_url": False,

    "title_tag": create_options_dict("div[class*=wp-block-title] a"),
    "url_tag": create_options_dict("div[class*=wp-block-title] a"),
    "address_tag": create_options_dict("address[class=voffset-bottom-10]"),
    "no_of_bedrooms_tag": create_options_dict(".fa-bed"),
    "no_of_bathrooms_tag": create_options_dict(".fa-bath"),
    "no_of_toilets_tag": create_options_dict(".fa-toilet"),
    "agent_contact_tag": create_options_dict(".marketed-by"),
    "price_tag": create_options_dict(".pull-sm-left"),
    "description_tag": create_options_dict(".description"),
    # "type_tag": create_options_dict(".table-bordered tr td", True),
    
    "get_parent": True,
}

property_pro = {
    "filename": "propertypro.csv",
    "url": "https://www.propertypro.ng",
    "search_url": "https://www.propertypro.ng/property-for-rent",
    "result_listing": create_options_dict(".listings-property"),
    "result_url": create_options_dict("/.+\?.+\d"),
    "use_patterns": False,
    "absolute_url": False,

    "title_tag": create_options_dict(".listings-property-title"),
    "url_tag": create_options_dict(".single-room-text > a"),
    "address_tag": create_options_dict(".single-room-text > h4"),
    "no_of_bedrooms_tag": create_options_dict(".fur-areea span:nth-child(1)"),
    "no_of_bathrooms_tag": create_options_dict(".fur-areea span:nth-child(2)"),
    "no_of_toilets_tag": create_options_dict(".fur-areea span:nth-child(3)"),
    "agent_contact_tag": create_options_dict(".phone-icon"),
    "price_tag": create_options_dict(".n50 h3"),
    "description_tag": create_options_dict(".description-text", True),
    # "type_tag": None,

    "get_parent": False,
}

# %%
websites = [nigeria_property, property_pro]
def start_crawler(sites) -> List[Crawler]:
    crawlers = []
    for site in websites:
        site_structure = Website(**site)
        site_crawler = Crawler(site_structure)
        site_crawler.crawl()
        crawlers.append(site_crawler)
        print("\n\nDone with a website\n\n\n")

    return crawlers

crawlers = start_crawler(websites)

with open('crawler.pkl', 'wb') as file:
    pickle.dump(crawlers, file)
# Out:
# Crawler started
# Done parsing https://nigeriapropertycentre.com/for-rent?page=2
# Done parsing https://nigeriapropertycentre.com/for-rent?page=3
# Done parsing https://nigeriapropertycentre.com/for-rent?page=4
# Done parsing https://nigeriapropertycentre.com/for-rent?page=5
# Done parsing https://nigeriapropertycentre.com/for-rent?page=6
# Done parsing https://nigeriapropertycentre.com/for-rent?page=7
# Done parsing https://nigeriapropertycentre.com/for-rent?page=8
# Done parsing https://nigeriapropertycentre.com/for-rent?page=997
# Done parsing https://nigeriapropertycentre.com/for-rent?page=998
# Done parsing https://nigeriapropertycentre.com/for-rent?page=9
# Done parsing https://nigeriapropertycentre.com/for-rent?page=10
# Done parsing https://nigeriapropertycentre.com/for-rent?page=11
# Done parsing https://nigeriapropertycentre.com/for-rent?page=996
# Done parsing https://nigeriapropertycentre.com/for-rent?page=990
# Done parsing https://nigeriapropertycentre.com/for-rent?page=991
# Done parsing https://nigeriapropertycentre.com/for-rent?page=992
# Done parsing https://nigeriapropertycentre.com/for-rent?page=993
# Done parsing https://nigeriapropertycentre.com/for-rent?page=994
# Done parsing https://nigeriapropertycentre.com/for-rent?page=995
# Done parsing https://nigeriapropertycentre.com/for-rent?page=12
# Have encounter an error at /for-rent?page=13
# Done parsing https://nigeriapropertycentre.com/for-rent?page=13
# Done parsing https://nigeriapropertycentre.com/for-rent?page=14
# Done parsing https://nigeriapropertycentre.com/for-rent?page=989
# Done parsing https://nigeriapropertycentre.com/for-rent?page=987
# Done parsing https://nigeriapropertycentre.com/for-rent?page=988
# Done parsing https://nigeriapropertycentre.com/for-rent?page=15
# Done parsing https://nigeriapropertycentre.com/for-rent?page=16
# Done parsing https://nigeriapropertycentre.com/for-rent?page=17
# Done parsing https://nigeriapropertycentre.com/for-rent?page=986
# Done parsing https://nigeriapropertycentre.com/for-rent?page=984
# Done parsing https://nigeriapropertycentre.com/for-rent?page=985
# Done parsing https://nigeriapropertycentre.com/for-rent?page=18
# Done parsing https://nigeriapropertycentre.com/for-rent?page=19
# Done parsing https://nigeriapropertycentre.com/for-rent?page=20
# Done parsing https://nigeriapropertycentre.com/for-rent?page=983
# Done parsing https://nigeriapropertycentre.com/for-rent?page=981
# Done parsing https://nigeriapropertycentre.com/for-rent?page=982
# Done parsing https://nigeriapropertycentre.com/for-rent?page=21
# Done parsing https://nigeriapropertycentre.com/for-rent?page=22
# Done parsing https://nigeriapropertycentre.com/for-rent?page=23
# Done parsing https://nigeriapropertycentre.com/for-rent?page=980
# Done parsing https://nigeriapropertycentre.com/for-rent?page=978
# Done parsing https://nigeriapropertycentre.com/for-rent?page=979
# Done parsing https://nigeriapropertycentre.com/for-rent?page=24
# Done parsing https://nigeriapropertycentre.com/for-rent?page=25
# Done parsing https://nigeriapropertycentre.com/for-rent?page=26
# Done parsing https://nigeriapropertycentre.com/for-rent?page=977
# Done parsing https://nigeriapropertycentre.com/for-rent?page=975
# Done parsing https://nigeriapropertycentre.com/for-rent?page=976
# Done parsing https://nigeriapropertycentre.com/for-rent?page=27
# Done parsing https://nigeriapropertycentre.com/for-rent?page=28
# Done parsing https://nigeriapropertycentre.com/for-rent?page=29
# Done parsing https://nigeriapropertycentre.com/for-rent?page=974
# Done parsing https://nigeriapropertycentre.com/for-rent?page=972
# Done parsing https://nigeriapropertycentre.com/for-rent?page=973
# Done parsing https://nigeriapropertycentre.com/for-rent?page=30
# Done parsing https://nigeriapropertycentre.com/for-rent?page=31
# Done parsing https://nigeriapropertycentre.com/for-rent?page=32
# Done parsing https://nigeriapropertycentre.com/for-rent?page=971
# Done parsing https://nigeriapropertycentre.com/for-rent?page=969
# Done parsing https://nigeriapropertycentre.com/for-rent?page=970
# Done parsing https://nigeriapropertycentre.com/for-rent?page=33
# Done parsing https://nigeriapropertycentre.com/for-rent?page=34
# Done parsing https://nigeriapropertycentre.com/for-rent?page=35
# Done parsing https://nigeriapropertycentre.com/for-rent?page=968
# Done parsing https://nigeriapropertycentre.com/for-rent?page=966
# Done parsing https://nigeriapropertycentre.com/for-rent?page=967
# Done parsing https://nigeriapropertycentre.com/for-rent?page=36
# Done parsing https://nigeriapropertycentre.com/for-rent?page=37
# Done parsing https://nigeriapropertycentre.com/for-rent?page=38
# Done parsing https://nigeriapropertycentre.com/for-rent?page=965
# Done parsing https://nigeriapropertycentre.com/for-rent?page=963
# Done parsing https://nigeriapropertycentre.com/for-rent?page=964
# Done parsing https://nigeriapropertycentre.com/for-rent?page=39
# Done parsing https://nigeriapropertycentre.com/for-rent?page=40
# Done parsing https://nigeriapropertycentre.com/for-rent?page=41
# Done parsing https://nigeriapropertycentre.com/for-rent?page=962
# Done parsing https://nigeriapropertycentre.com/for-rent?page=960
# Done parsing https://nigeriapropertycentre.com/for-rent?page=961
# Done parsing https://nigeriapropertycentre.com/for-rent?page=42
# Done parsing https://nigeriapropertycentre.com/for-rent?page=43
# Done parsing https://nigeriapropertycentre.com/for-rent?page=44
# Done parsing https://nigeriapropertycentre.com/for-rent?page=959
# Done parsing https://nigeriapropertycentre.com/for-rent?page=957
# Done parsing https://nigeriapropertycentre.com/for-rent?page=958
# Done parsing https://nigeriapropertycentre.com/for-rent?page=45
# Done parsing https://nigeriapropertycentre.com/for-rent?page=46
# Done parsing https://nigeriapropertycentre.com/for-rent?page=47
# Done parsing https://nigeriapropertycentre.com/for-rent?page=956
# Done parsing https://nigeriapropertycentre.com/for-rent?page=954
# Done parsing https://nigeriapropertycentre.com/for-rent?page=955
# Done parsing https://nigeriapropertycentre.com/for-rent?page=48
# Done parsing https://nigeriapropertycentre.com/for-rent?page=49
# Done parsing https://nigeriapropertycentre.com/for-rent?page=50
# Done parsing https://nigeriapropertycentre.com/for-rent?page=953
# Done parsing https://nigeriapropertycentre.com/for-rent?page=951
# Done parsing https://nigeriapropertycentre.com/for-rent?page=952
# Done parsing https://nigeriapropertycentre.com/for-rent?page=51
# Done parsing https://nigeriapropertycentre.com/for-rent?page=52
# Done parsing https://nigeriapropertycentre.com/for-rent?page=53
# Done parsing https://nigeriapropertycentre.com/for-rent?page=950
# Done parsing https://nigeriapropertycentre.com/for-rent?page=948
# Done parsing https://nigeriapropertycentre.com/for-rent?page=949
# Done parsing https://nigeriapropertycentre.com/for-rent?page=54
# Done parsing https://nigeriapropertycentre.com/for-rent?page=55
# Have encounter an error at /for-rent?page=56
# Done parsing https://nigeriapropertycentre.com/for-rent?page=947
# Done parsing https://nigeriapropertycentre.com/for-rent?page=945
# Done parsing https://nigeriapropertycentre.com/for-rent?page=946
# Done parsing https://nigeriapropertycentre.com/for-rent?page=56
# Done parsing https://nigeriapropertycentre.com/for-rent?page=57
# Done parsing https://nigeriapropertycentre.com/for-rent?page=58
# Done parsing https://nigeriapropertycentre.com/for-rent?page=944
# Done parsing https://nigeriapropertycentre.com/for-rent?page=942
# Done parsing https://nigeriapropertycentre.com/for-rent?page=943
# Done parsing https://nigeriapropertycentre.com/for-rent?page=59
# Done parsing https://nigeriapropertycentre.com/for-rent?page=60
# Done parsing https://nigeriapropertycentre.com/for-rent?page=61
# Done parsing https://nigeriapropertycentre.com/for-rent?page=941
# Done parsing https://nigeriapropertycentre.com/for-rent?page=939
# Done parsing https://nigeriapropertycentre.com/for-rent?page=940
# Done parsing https://nigeriapropertycentre.com/for-rent?page=62
# Done parsing https://nigeriapropertycentre.com/for-rent?page=63
# Done parsing https://nigeriapropertycentre.com/for-rent?page=64
# Done parsing https://nigeriapropertycentre.com/for-rent?page=938
# Done parsing https://nigeriapropertycentre.com/for-rent?page=936
# Done parsing https://nigeriapropertycentre.com/for-rent?page=937
# Done parsing https://nigeriapropertycentre.com/for-rent?page=65
# Done parsing https://nigeriapropertycentre.com/for-rent?page=66
# Done parsing https://nigeriapropertycentre.com/for-rent?page=67
# Done parsing https://nigeriapropertycentre.com/for-rent?page=935
# Done parsing https://nigeriapropertycentre.com/for-rent?page=933
# Done parsing https://nigeriapropertycentre.com/for-rent?page=934
# Done parsing https://nigeriapropertycentre.com/for-rent?page=68
# Done parsing https://nigeriapropertycentre.com/for-rent?page=69
# Done parsing https://nigeriapropertycentre.com/for-rent?page=70
# Done parsing https://nigeriapropertycentre.com/for-rent?page=932
# Done parsing https://nigeriapropertycentre.com/for-rent?page=930
# Done parsing https://nigeriapropertycentre.com/for-rent?page=931
# Done parsing https://nigeriapropertycentre.com/for-rent?page=71
# Done parsing https://nigeriapropertycentre.com/for-rent?page=72
# Done parsing https://nigeriapropertycentre.com/for-rent?page=73
# Done parsing https://nigeriapropertycentre.com/for-rent?page=929
# Done parsing https://nigeriapropertycentre.com/for-rent?page=927
# Done parsing https://nigeriapropertycentre.com/for-rent?page=928
# Done parsing https://nigeriapropertycentre.com/for-rent?page=74
# Done parsing https://nigeriapropertycentre.com/for-rent?page=75
# Done parsing https://nigeriapropertycentre.com/for-rent?page=76
# Done parsing https://nigeriapropertycentre.com/for-rent?page=926
# Done parsing https://nigeriapropertycentre.com/for-rent?page=924
# Done parsing https://nigeriapropertycentre.com/for-rent?page=925
# Done parsing https://nigeriapropertycentre.com/for-rent?page=77
# Done parsing https://nigeriapropertycentre.com/for-rent?page=78
# Done parsing https://nigeriapropertycentre.com/for-rent?page=79
# Done parsing https://nigeriapropertycentre.com/for-rent?page=923
# Done parsing https://nigeriapropertycentre.com/for-rent?page=921
# Done parsing https://nigeriapropertycentre.com/for-rent?page=922
# Done parsing https://nigeriapropertycentre.com/for-rent?page=80
# Done parsing https://nigeriapropertycentre.com/for-rent?page=81
# Done parsing https://nigeriapropertycentre.com/for-rent?page=82
# Done parsing https://nigeriapropertycentre.com/for-rent?page=920
# Done parsing https://nigeriapropertycentre.com/for-rent?page=918
# Done parsing https://nigeriapropertycentre.com/for-rent?page=919
# Done parsing https://nigeriapropertycentre.com/for-rent?page=83
# Done parsing https://nigeriapropertycentre.com/for-rent?page=84
# Done parsing https://nigeriapropertycentre.com/for-rent?page=85
# Done parsing https://nigeriapropertycentre.com/for-rent?page=917
# Done parsing https://nigeriapropertycentre.com/for-rent?page=915
# Done parsing https://nigeriapropertycentre.com/for-rent?page=916
# Done parsing https://nigeriapropertycentre.com/for-rent?page=86
# Done parsing https://nigeriapropertycentre.com/for-rent?page=87
# Done parsing https://nigeriapropertycentre.com/for-rent?page=88
# Done parsing https://nigeriapropertycentre.com/for-rent?page=914
# Done parsing https://nigeriapropertycentre.com/for-rent?page=912
# Done parsing https://nigeriapropertycentre.com/for-rent?page=913
# Done parsing https://nigeriapropertycentre.com/for-rent?page=89
# Done parsing https://nigeriapropertycentre.com/for-rent?page=90
# Done parsing https://nigeriapropertycentre.com/for-rent?page=91
# Done parsing https://nigeriapropertycentre.com/for-rent?page=911
# Done parsing https://nigeriapropertycentre.com/for-rent?page=909
# Done parsing https://nigeriapropertycentre.com/for-rent?page=910
# Done parsing https://nigeriapropertycentre.com/for-rent?page=92
# Done parsing https://nigeriapropertycentre.com/for-rent?page=93
# Done parsing https://nigeriapropertycentre.com/for-rent?page=94
# Done parsing https://nigeriapropertycentre.com/for-rent?page=908
# Done parsing https://nigeriapropertycentre.com/for-rent?page=906
# Done parsing https://nigeriapropertycentre.com/for-rent?page=907
# Done parsing https://nigeriapropertycentre.com/for-rent?page=95
# Done parsing https://nigeriapropertycentre.com/for-rent?page=96
# Done parsing https://nigeriapropertycentre.com/for-rent?page=97
# Done parsing https://nigeriapropertycentre.com/for-rent?page=905
# Done parsing https://nigeriapropertycentre.com/for-rent?page=903
# Done parsing https://nigeriapropertycentre.com/for-rent?page=904
# Done parsing https://nigeriapropertycentre.com/for-rent?page=98
# Done parsing https://nigeriapropertycentre.com/for-rent?page=99
# Done parsing https://nigeriapropertycentre.com/for-rent?page=100
# Done parsing https://nigeriapropertycentre.com/for-rent?page=902
# Done parsing https://nigeriapropertycentre.com/for-rent?page=900
# Done parsing https://nigeriapropertycentre.com/for-rent?page=901
# Done parsing https://nigeriapropertycentre.com/for-rent?page=101
# Done parsing https://nigeriapropertycentre.com/for-rent?page=102
# Done parsing https://nigeriapropertycentre.com/for-rent?page=103
# Done parsing https://nigeriapropertycentre.com/for-rent?page=899
# Done parsing https://nigeriapropertycentre.com/for-rent?page=897
# Done parsing https://nigeriapropertycentre.com/for-rent?page=898
# Done parsing https://nigeriapropertycentre.com/for-rent?page=104
# Done parsing https://nigeriapropertycentre.com/for-rent?page=105
# Done parsing https://nigeriapropertycentre.com/for-rent?page=106
# Done parsing https://nigeriapropertycentre.com/for-rent?page=896
# Done parsing https://nigeriapropertycentre.com/for-rent?page=894
# Done parsing https://nigeriapropertycentre.com/for-rent?page=895
# Done parsing https://nigeriapropertycentre.com/for-rent?page=107
# Done parsing https://nigeriapropertycentre.com/for-rent?page=108
# Done parsing https://nigeriapropertycentre.com/for-rent?page=109
# Done parsing https://nigeriapropertycentre.com/for-rent?page=893
# Done parsing https://nigeriapropertycentre.com/for-rent?page=891
# Done parsing https://nigeriapropertycentre.com/for-rent?page=892
# Done parsing https://nigeriapropertycentre.com/for-rent?page=110
# Done parsing https://nigeriapropertycentre.com/for-rent?page=111
# Done parsing https://nigeriapropertycentre.com/for-rent?page=112
# Done parsing https://nigeriapropertycentre.com/for-rent?page=890
# Done parsing https://nigeriapropertycentre.com/for-rent?page=888
# Done parsing https://nigeriapropertycentre.com/for-rent?page=889
# Done parsing https://nigeriapropertycentre.com/for-rent?page=113
# Done parsing https://nigeriapropertycentre.com/for-rent?page=114
# Done parsing https://nigeriapropertycentre.com/for-rent?page=115
# Done parsing https://nigeriapropertycentre.com/for-rent?page=887
# Done parsing https://nigeriapropertycentre.com/for-rent?page=885
# Done parsing https://nigeriapropertycentre.com/for-rent?page=886
# Done parsing https://nigeriapropertycentre.com/for-rent?page=116
# Done parsing https://nigeriapropertycentre.com/for-rent?page=117
# Done parsing https://nigeriapropertycentre.com/for-rent?page=118
# Done parsing https://nigeriapropertycentre.com/for-rent?page=884
# Done parsing https://nigeriapropertycentre.com/for-rent?page=882
# Done parsing https://nigeriapropertycentre.com/for-rent?page=883
# Done parsing https://nigeriapropertycentre.com/for-rent?page=119
# Done parsing https://nigeriapropertycentre.com/for-rent?page=120
# Done parsing https://nigeriapropertycentre.com/for-rent?page=121
# Done parsing https://nigeriapropertycentre.com/for-rent?page=881
# Done parsing https://nigeriapropertycentre.com/for-rent?page=879
# Done parsing https://nigeriapropertycentre.com/for-rent?page=880
# Done parsing https://nigeriapropertycentre.com/for-rent?page=122
# Done parsing https://nigeriapropertycentre.com/for-rent?page=123
# Done parsing https://nigeriapropertycentre.com/for-rent?page=124
# Done parsing https://nigeriapropertycentre.com/for-rent?page=878
# Done parsing https://nigeriapropertycentre.com/for-rent?page=876
# Done parsing https://nigeriapropertycentre.com/for-rent?page=877
# Done parsing https://nigeriapropertycentre.com/for-rent?page=125
# Done parsing https://nigeriapropertycentre.com/for-rent?page=126
# Done parsing https://nigeriapropertycentre.com/for-rent?page=127
# Done parsing https://nigeriapropertycentre.com/for-rent?page=875
# Done parsing https://nigeriapropertycentre.com/for-rent?page=873
# Done parsing https://nigeriapropertycentre.com/for-rent?page=874
# Done parsing https://nigeriapropertycentre.com/for-rent?page=128
# Done parsing https://nigeriapropertycentre.com/for-rent?page=129
# Done parsing https://nigeriapropertycentre.com/for-rent?page=130
# Done parsing https://nigeriapropertycentre.com/for-rent?page=872
# Done parsing https://nigeriapropertycentre.com/for-rent?page=870
# Done parsing https://nigeriapropertycentre.com/for-rent?page=871
# Done parsing https://nigeriapropertycentre.com/for-rent?page=131
# Done parsing https://nigeriapropertycentre.com/for-rent?page=132
# Done parsing https://nigeriapropertycentre.com/for-rent?page=133
# Done parsing https://nigeriapropertycentre.com/for-rent?page=869
# Done parsing https://nigeriapropertycentre.com/for-rent?page=867
# Done parsing https://nigeriapropertycentre.com/for-rent?page=868
# Done parsing https://nigeriapropertycentre.com/for-rent?page=134
# Done parsing https://nigeriapropertycentre.com/for-rent?page=135
# Done parsing https://nigeriapropertycentre.com/for-rent?page=136
# Done parsing https://nigeriapropertycentre.com/for-rent?page=866
# Done parsing https://nigeriapropertycentre.com/for-rent?page=864
# Done parsing https://nigeriapropertycentre.com/for-rent?page=865
# Done parsing https://nigeriapropertycentre.com/for-rent?page=137
# Done parsing https://nigeriapropertycentre.com/for-rent?page=138
# Done parsing https://nigeriapropertycentre.com/for-rent?page=139
# Done parsing https://nigeriapropertycentre.com/for-rent?page=863
# Done parsing https://nigeriapropertycentre.com/for-rent?page=861
# Done parsing https://nigeriapropertycentre.com/for-rent?page=862
# Done parsing https://nigeriapropertycentre.com/for-rent?page=140
# Done parsing https://nigeriapropertycentre.com/for-rent?page=141
# Done parsing https://nigeriapropertycentre.com/for-rent?page=142
# Done parsing https://nigeriapropertycentre.com/for-rent?page=860
# Done parsing https://nigeriapropertycentre.com/for-rent?page=858
# Done parsing https://nigeriapropertycentre.com/for-rent?page=859
# Done parsing https://nigeriapropertycentre.com/for-rent?page=143
# Done parsing https://nigeriapropertycentre.com/for-rent?page=144
# Done parsing https://nigeriapropertycentre.com/for-rent?page=145
# Done parsing https://nigeriapropertycentre.com/for-rent?page=857
# Done parsing https://nigeriapropertycentre.com/for-rent?page=855
# Done parsing https://nigeriapropertycentre.com/for-rent?page=856
# Done parsing https://nigeriapropertycentre.com/for-rent?page=146
# Done parsing https://nigeriapropertycentre.com/for-rent?page=147
# Done parsing https://nigeriapropertycentre.com/for-rent?page=148
# Done parsing https://nigeriapropertycentre.com/for-rent?page=854
# Done parsing https://nigeriapropertycentre.com/for-rent?page=852
# Done parsing https://nigeriapropertycentre.com/for-rent?page=853
# Done parsing https://nigeriapropertycentre.com/for-rent?page=149
# Done parsing https://nigeriapropertycentre.com/for-rent?page=150
# Done parsing https://nigeriapropertycentre.com/for-rent?page=151
# Done parsing https://nigeriapropertycentre.com/for-rent?page=851
# Done parsing https://nigeriapropertycentre.com/for-rent?page=849
# Done parsing https://nigeriapropertycentre.com/for-rent?page=850
# Done parsing https://nigeriapropertycentre.com/for-rent?page=152
# Done parsing https://nigeriapropertycentre.com/for-rent?page=153
# Done parsing https://nigeriapropertycentre.com/for-rent?page=154
# Done parsing https://nigeriapropertycentre.com/for-rent?page=848
# Done parsing https://nigeriapropertycentre.com/for-rent?page=846
# Done parsing https://nigeriapropertycentre.com/for-rent?page=847
# Done parsing https://nigeriapropertycentre.com/for-rent?page=155
# Done parsing https://nigeriapropertycentre.com/for-rent?page=156
# Done parsing https://nigeriapropertycentre.com/for-rent?page=157
# Done parsing https://nigeriapropertycentre.com/for-rent?page=845
# Done parsing https://nigeriapropertycentre.com/for-rent?page=843
# Done parsing https://nigeriapropertycentre.com/for-rent?page=844
# Done parsing https://nigeriapropertycentre.com/for-rent?page=158
# Done parsing https://nigeriapropertycentre.com/for-rent?page=159
# Done parsing https://nigeriapropertycentre.com/for-rent?page=160
# Done parsing https://nigeriapropertycentre.com/for-rent?page=842
# Done parsing https://nigeriapropertycentre.com/for-rent?page=840
# Done parsing https://nigeriapropertycentre.com/for-rent?page=841
# Done parsing https://nigeriapropertycentre.com/for-rent?page=161
# Done parsing https://nigeriapropertycentre.com/for-rent?page=162
# Done parsing https://nigeriapropertycentre.com/for-rent?page=999
# Done parsing https://nigeriapropertycentre.com/for-rent?page=163
# Done parsing https://nigeriapropertycentre.com/for-rent?page=839
# Done parsing https://nigeriapropertycentre.com/for-rent?page=837
# Done parsing https://nigeriapropertycentre.com/for-rent?page=838
# Done parsing https://nigeriapropertycentre.com/for-rent?page=164
# Done parsing https://nigeriapropertycentre.com/for-rent?page=165
# Done parsing https://nigeriapropertycentre.com/for-rent?page=166
# Done parsing https://nigeriapropertycentre.com/for-rent?page=836
# Done parsing https://nigeriapropertycentre.com/for-rent?page=834
# Done parsing https://nigeriapropertycentre.com/for-rent?page=835
# Done parsing https://nigeriapropertycentre.com/for-rent?page=167
# Done parsing https://nigeriapropertycentre.com/for-rent?page=168
# Done parsing https://nigeriapropertycentre.com/for-rent?page=169
# Done parsing https://nigeriapropertycentre.com/for-rent?page=833
# Done parsing https://nigeriapropertycentre.com/for-rent?page=831
# Done parsing https://nigeriapropertycentre.com/for-rent?page=832
# Done parsing https://nigeriapropertycentre.com/for-rent?page=170
# Done parsing https://nigeriapropertycentre.com/for-rent?page=171
# Done parsing https://nigeriapropertycentre.com/for-rent?page=172
# Done parsing https://nigeriapropertycentre.com/for-rent?page=830
# Done parsing https://nigeriapropertycentre.com/for-rent?page=828
# Done parsing https://nigeriapropertycentre.com/for-rent?page=829
# Done parsing https://nigeriapropertycentre.com/for-rent?page=173
# Done parsing https://nigeriapropertycentre.com/for-rent?page=174
# Done parsing https://nigeriapropertycentre.com/for-rent?page=175
# Done parsing https://nigeriapropertycentre.com/for-rent?page=827
# Done parsing https://nigeriapropertycentre.com/for-rent?page=825
# Done parsing https://nigeriapropertycentre.com/for-rent?page=826
# Done parsing https://nigeriapropertycentre.com/for-rent?page=176
# Done parsing https://nigeriapropertycentre.com/for-rent?page=177
# Done parsing https://nigeriapropertycentre.com/for-rent?page=178
# Done parsing https://nigeriapropertycentre.com/for-rent?page=824
# Done parsing https://nigeriapropertycentre.com/for-rent?page=822
# Done parsing https://nigeriapropertycentre.com/for-rent?page=823
# Done parsing https://nigeriapropertycentre.com/for-rent?page=179
# Done parsing https://nigeriapropertycentre.com/for-rent?page=180
# Done parsing https://nigeriapropertycentre.com/for-rent?page=181
# Done parsing https://nigeriapropertycentre.com/for-rent?page=821
# Done parsing https://nigeriapropertycentre.com/for-rent?page=819
# Done parsing https://nigeriapropertycentre.com/for-rent?page=820
# Done parsing https://nigeriapropertycentre.com/for-rent?page=182
# Done parsing https://nigeriapropertycentre.com/for-rent?page=183
# Done parsing https://nigeriapropertycentre.com/for-rent?page=184
# Done parsing https://nigeriapropertycentre.com/for-rent?page=818
# Done parsing https://nigeriapropertycentre.com/for-rent?page=816
# Done parsing https://nigeriapropertycentre.com/for-rent?page=817
# Done parsing https://nigeriapropertycentre.com/for-rent?page=185
# Done parsing https://nigeriapropertycentre.com/for-rent?page=186
# Done parsing https://nigeriapropertycentre.com/for-rent?page=187
# Done parsing https://nigeriapropertycentre.com/for-rent?page=815
# Done parsing https://nigeriapropertycentre.com/for-rent?page=813
# Done parsing https://nigeriapropertycentre.com/for-rent?page=814
# Done parsing https://nigeriapropertycentre.com/for-rent?page=188
# Done parsing https://nigeriapropertycentre.com/for-rent?page=189
# Done parsing https://nigeriapropertycentre.com/for-rent?page=190
# Done parsing https://nigeriapropertycentre.com/for-rent?page=812
# Done parsing https://nigeriapropertycentre.com/for-rent?page=810
# Done parsing https://nigeriapropertycentre.com/for-rent?page=811
# Done parsing https://nigeriapropertycentre.com/for-rent?page=191
# Done parsing https://nigeriapropertycentre.com/for-rent?page=192
# Done parsing https://nigeriapropertycentre.com/for-rent?page=193
# Done parsing https://nigeriapropertycentre.com/for-rent?page=809
# Done parsing https://nigeriapropertycentre.com/for-rent?page=807
# Done parsing https://nigeriapropertycentre.com/for-rent?page=808
# Done parsing https://nigeriapropertycentre.com/for-rent?page=194
# Done parsing https://nigeriapropertycentre.com/for-rent?page=195
# Done parsing https://nigeriapropertycentre.com/for-rent?page=196
# Done parsing https://nigeriapropertycentre.com/for-rent?page=806
# Done parsing https://nigeriapropertycentre.com/for-rent?page=804
# Done parsing https://nigeriapropertycentre.com/for-rent?page=805
# Done parsing https://nigeriapropertycentre.com/for-rent?page=197
# Done parsing https://nigeriapropertycentre.com/for-rent?page=198
# Done parsing https://nigeriapropertycentre.com/for-rent?page=199
# Done parsing https://nigeriapropertycentre.com/for-rent?page=803
# Done parsing https://nigeriapropertycentre.com/for-rent?page=801
# Done parsing https://nigeriapropertycentre.com/for-rent?page=802
# Done parsing https://nigeriapropertycentre.com/for-rent?page=200
# Done parsing https://nigeriapropertycentre.com/for-rent?page=201
# Done parsing https://nigeriapropertycentre.com/for-rent?page=202
# Done parsing https://nigeriapropertycentre.com/for-rent?page=800
# Done parsing https://nigeriapropertycentre.com/for-rent?page=798
# Done parsing https://nigeriapropertycentre.com/for-rent?page=799
# Done parsing https://nigeriapropertycentre.com/for-rent?page=203
# Done parsing https://nigeriapropertycentre.com/for-rent?page=204
# Done parsing https://nigeriapropertycentre.com/for-rent?page=205
# Done parsing https://nigeriapropertycentre.com/for-rent?page=797
# Done parsing https://nigeriapropertycentre.com/for-rent?page=795
# Done parsing https://nigeriapropertycentre.com/for-rent?page=796
# Done parsing https://nigeriapropertycentre.com/for-rent?page=206
# Done parsing https://nigeriapropertycentre.com/for-rent?page=207
# Done parsing https://nigeriapropertycentre.com/for-rent?page=208
# Done parsing https://nigeriapropertycentre.com/for-rent?page=794
# Done parsing https://nigeriapropertycentre.com/for-rent?page=792
# Done parsing https://nigeriapropertycentre.com/for-rent?page=793
# Done parsing https://nigeriapropertycentre.com/for-rent?page=209
# Done parsing https://nigeriapropertycentre.com/for-rent?page=210
# Done parsing https://nigeriapropertycentre.com/for-rent?page=211
# Done parsing https://nigeriapropertycentre.com/for-rent?page=791
# Done parsing https://nigeriapropertycentre.com/for-rent?page=789
# Done parsing https://nigeriapropertycentre.com/for-rent?page=790
# Done parsing https://nigeriapropertycentre.com/for-rent?page=212
# Done parsing https://nigeriapropertycentre.com/for-rent?page=213
# Done parsing https://nigeriapropertycentre.com/for-rent?page=214
# Done parsing https://nigeriapropertycentre.com/for-rent?page=788
# Done parsing https://nigeriapropertycentre.com/for-rent?page=786
# Done parsing https://nigeriapropertycentre.com/for-rent?page=787
# Done parsing https://nigeriapropertycentre.com/for-rent?page=215
# Done parsing https://nigeriapropertycentre.com/for-rent?page=216
# Done parsing https://nigeriapropertycentre.com/for-rent?page=217
# Done parsing https://nigeriapropertycentre.com/for-rent?page=785
# Done parsing https://nigeriapropertycentre.com/for-rent?page=783
# Done parsing https://nigeriapropertycentre.com/for-rent?page=784
# Done parsing https://nigeriapropertycentre.com/for-rent?page=218
# Done parsing https://nigeriapropertycentre.com/for-rent?page=219
# Done parsing https://nigeriapropertycentre.com/for-rent?page=220
# Done parsing https://nigeriapropertycentre.com/for-rent?page=782
# Done parsing https://nigeriapropertycentre.com/for-rent?page=780
# Done parsing https://nigeriapropertycentre.com/for-rent?page=781
# Done parsing https://nigeriapropertycentre.com/for-rent?page=221
# Done parsing https://nigeriapropertycentre.com/for-rent?page=222
# Done parsing https://nigeriapropertycentre.com/for-rent?page=223
# Done parsing https://nigeriapropertycentre.com/for-rent?page=779
# Done parsing https://nigeriapropertycentre.com/for-rent?page=777
# Done parsing https://nigeriapropertycentre.com/for-rent?page=778
# Done parsing https://nigeriapropertycentre.com/for-rent?page=224
# Done parsing https://nigeriapropertycentre.com/for-rent?page=225
# Done parsing https://nigeriapropertycentre.com/for-rent?page=226
# Done parsing https://nigeriapropertycentre.com/for-rent?page=776
# Done parsing https://nigeriapropertycentre.com/for-rent?page=774
# Done parsing https://nigeriapropertycentre.com/for-rent?page=775
# Done parsing https://nigeriapropertycentre.com/for-rent?page=227
# Done parsing https://nigeriapropertycentre.com/for-rent?page=228
# Done parsing https://nigeriapropertycentre.com/for-rent?page=229
# Done parsing https://nigeriapropertycentre.com/for-rent?page=773
# Done parsing https://nigeriapropertycentre.com/for-rent?page=771
# Done parsing https://nigeriapropertycentre.com/for-rent?page=772
# Done parsing https://nigeriapropertycentre.com/for-rent?page=230
# Done parsing https://nigeriapropertycentre.com/for-rent?page=231
# Done parsing https://nigeriapropertycentre.com/for-rent?page=232
# Done parsing https://nigeriapropertycentre.com/for-rent?page=770
# Done parsing https://nigeriapropertycentre.com/for-rent?page=768
# Done parsing https://nigeriapropertycentre.com/for-rent?page=769
# Done parsing https://nigeriapropertycentre.com/for-rent?page=233
# Done parsing https://nigeriapropertycentre.com/for-rent?page=234
# Done parsing https://nigeriapropertycentre.com/for-rent?page=235
# Done parsing https://nigeriapropertycentre.com/for-rent?page=767
# Done parsing https://nigeriapropertycentre.com/for-rent?page=765
# Done parsing https://nigeriapropertycentre.com/for-rent?page=766
# Done parsing https://nigeriapropertycentre.com/for-rent?page=236
# Done parsing https://nigeriapropertycentre.com/for-rent?page=237
# Done parsing https://nigeriapropertycentre.com/for-rent?page=238
# Done parsing https://nigeriapropertycentre.com/for-rent?page=764
# Done parsing https://nigeriapropertycentre.com/for-rent?page=762
# Done parsing https://nigeriapropertycentre.com/for-rent?page=763
# Done parsing https://nigeriapropertycentre.com/for-rent?page=239
# Done parsing https://nigeriapropertycentre.com/for-rent?page=240
# Done parsing https://nigeriapropertycentre.com/for-rent?page=241
# Done parsing https://nigeriapropertycentre.com/for-rent?page=761
# Done parsing https://nigeriapropertycentre.com/for-rent?page=759
# Done parsing https://nigeriapropertycentre.com/for-rent?page=760
# Done parsing https://nigeriapropertycentre.com/for-rent?page=242
# Done parsing https://nigeriapropertycentre.com/for-rent?page=243
# Done parsing https://nigeriapropertycentre.com/for-rent?page=244
# Done parsing https://nigeriapropertycentre.com/for-rent?page=758
# Done parsing https://nigeriapropertycentre.com/for-rent?page=756
# Done parsing https://nigeriapropertycentre.com/for-rent?page=757
# Done parsing https://nigeriapropertycentre.com/for-rent?page=245
# Done parsing https://nigeriapropertycentre.com/for-rent?page=246
# Done parsing https://nigeriapropertycentre.com/for-rent?page=247
# Done parsing https://nigeriapropertycentre.com/for-rent?page=755
# Done parsing https://nigeriapropertycentre.com/for-rent?page=753
# Done parsing https://nigeriapropertycentre.com/for-rent?page=754
# Done parsing https://nigeriapropertycentre.com/for-rent?page=248
# Done parsing https://nigeriapropertycentre.com/for-rent?page=249
# Done parsing https://nigeriapropertycentre.com/for-rent?page=250
# Done parsing https://nigeriapropertycentre.com/for-rent?page=752
# Done parsing https://nigeriapropertycentre.com/for-rent?page=750
# Done parsing https://nigeriapropertycentre.com/for-rent?page=751
# Done parsing https://nigeriapropertycentre.com/for-rent?page=251
# Done parsing https://nigeriapropertycentre.com/for-rent?page=252
# Done parsing https://nigeriapropertycentre.com/for-rent?page=253
# Done parsing https://nigeriapropertycentre.com/for-rent?page=749
# Done parsing https://nigeriapropertycentre.com/for-rent?page=747
# Done parsing https://nigeriapropertycentre.com/for-rent?page=748
# Done parsing https://nigeriapropertycentre.com/for-rent?page=254
# Done parsing https://nigeriapropertycentre.com/for-rent?page=255
# Done parsing https://nigeriapropertycentre.com/for-rent?page=256
# Done parsing https://nigeriapropertycentre.com/for-rent?page=746
# Done parsing https://nigeriapropertycentre.com/for-rent?page=744
# Done parsing https://nigeriapropertycentre.com/for-rent?page=745
# Done parsing https://nigeriapropertycentre.com/for-rent?page=257
# Done parsing https://nigeriapropertycentre.com/for-rent?page=258
# Done parsing https://nigeriapropertycentre.com/for-rent?page=259
# Done parsing https://nigeriapropertycentre.com/for-rent?page=743
# Done parsing https://nigeriapropertycentre.com/for-rent?page=741
# Done parsing https://nigeriapropertycentre.com/for-rent?page=742
# Done parsing https://nigeriapropertycentre.com/for-rent?page=260
# Done parsing https://nigeriapropertycentre.com/for-rent?page=261
# Done parsing https://nigeriapropertycentre.com/for-rent?page=262
# Done parsing https://nigeriapropertycentre.com/for-rent?page=740
# Done parsing https://nigeriapropertycentre.com/for-rent?page=738
# Done parsing https://nigeriapropertycentre.com/for-rent?page=739
# Done parsing https://nigeriapropertycentre.com/for-rent?page=263
# Done parsing https://nigeriapropertycentre.com/for-rent?page=264
# Done parsing https://nigeriapropertycentre.com/for-rent?page=265
# Done parsing https://nigeriapropertycentre.com/for-rent?page=737
# Done parsing https://nigeriapropertycentre.com/for-rent?page=735
# Done parsing https://nigeriapropertycentre.com/for-rent?page=736
# Done parsing https://nigeriapropertycentre.com/for-rent?page=266
# Done parsing https://nigeriapropertycentre.com/for-rent?page=267
# Done parsing https://nigeriapropertycentre.com/for-rent?page=268
# Done parsing https://nigeriapropertycentre.com/for-rent?page=734
# Done parsing https://nigeriapropertycentre.com/for-rent?page=732
# Done parsing https://nigeriapropertycentre.com/for-rent?page=733
# Done parsing https://nigeriapropertycentre.com/for-rent?page=269
# Done parsing https://nigeriapropertycentre.com/for-rent?page=270
# Done parsing https://nigeriapropertycentre.com/for-rent?page=271
# Done parsing https://nigeriapropertycentre.com/for-rent?page=731
# Done parsing https://nigeriapropertycentre.com/for-rent?page=729
# Done parsing https://nigeriapropertycentre.com/for-rent?page=730
# Done parsing https://nigeriapropertycentre.com/for-rent?page=272
# Done parsing https://nigeriapropertycentre.com/for-rent?page=273
# Done parsing https://nigeriapropertycentre.com/for-rent?page=274
# Done parsing https://nigeriapropertycentre.com/for-rent?page=728
# Done parsing https://nigeriapropertycentre.com/for-rent?page=726
# Done parsing https://nigeriapropertycentre.com/for-rent?page=727
# Done parsing https://nigeriapropertycentre.com/for-rent?page=275
# Done parsing https://nigeriapropertycentre.com/for-rent?page=276
# Done parsing https://nigeriapropertycentre.com/for-rent?page=277
# Done parsing https://nigeriapropertycentre.com/for-rent?page=725
# Done parsing https://nigeriapropertycentre.com/for-rent?page=723
# Done parsing https://nigeriapropertycentre.com/for-rent?page=724
# Done parsing https://nigeriapropertycentre.com/for-rent?page=278
# Done parsing https://nigeriapropertycentre.com/for-rent?page=279
# Done parsing https://nigeriapropertycentre.com/for-rent?page=280
# Done parsing https://nigeriapropertycentre.com/for-rent?page=722
# Done parsing https://nigeriapropertycentre.com/for-rent?page=720
# Done parsing https://nigeriapropertycentre.com/for-rent?page=721
# Done parsing https://nigeriapropertycentre.com/for-rent?page=281
# Done parsing https://nigeriapropertycentre.com/for-rent?page=282
# Done parsing https://nigeriapropertycentre.com/for-rent?page=283
# Done parsing https://nigeriapropertycentre.com/for-rent?page=719
# Done parsing https://nigeriapropertycentre.com/for-rent?page=717
# Done parsing https://nigeriapropertycentre.com/for-rent?page=718
# Done parsing https://nigeriapropertycentre.com/for-rent?page=284
# Done parsing https://nigeriapropertycentre.com/for-rent?page=285
# Done parsing https://nigeriapropertycentre.com/for-rent?page=286
# Done parsing https://nigeriapropertycentre.com/for-rent?page=716
# Done parsing https://nigeriapropertycentre.com/for-rent?page=714
# Done parsing https://nigeriapropertycentre.com/for-rent?page=715

# %%
def save_to_db(Title, URL, Address, No_of_Bedrooms, No_of_Bathrooms, 
              No_of_Toilets, Agent_Contact, Price):
    
    Title = Title.replace("'", "''")
    Address = Address.replace("'", "''")
    Agent_Contact = Agent_Contact.replace("'", "''")
    Price = Price.replace("'", "''")
    
    query = fr"""INSERT INTO house_rent (title, url, address, no_of_bedrooms, no_of_bathrooms, no_of_toilets, agent_contact, price)
                VALUES ('{Title}', '{URL}', '{Address}', '{No_of_Bedrooms}', '{No_of_Bathrooms}', '{No_of_Toilets}', '{Agent_Contact}', '{Price}')
                        """
    db.query(query)

# %%
url = "https://nigeriapropertycentre.com/for-rent"

# %%
bs = BeautifulSoup(requests.get(url).content)

# %%
bs.select("div[itemtype*=ListItem]")[0]
# Out:
# <div class="row property-list highlight-property" itemprop="itemListElement" itemscope="" itemtype="https://schema.org/ListItem">
# <meta content="1" itemprop="position"/>
# <link href="https://schema.org/RealEstateListing" itemprop="additionalType"/>
# <div class="col-md-12">
# <div class="wp-block property list">
# <div class="ribbon base-alt hidden-xs"><span>Premium Plus Listing</span></div>
# <div class="wp-block-title hidden-xs">
# <a hidefocus="true" href="/for-rent/event-centre-venue/conference-meeting-training-rooms/lagos/ikeja/ogba/562133-boat-house-training-and-event-center" itemprop="url"><h3 itemprop="name">Boat House Training And Event Center</h3></a>
# </div>
# <div class="wp-block-body">
# <div class="wp-block-img text-center">
# <a hidefocus="true" href="/for-rent/event-centre-venue/conference-meeting-training-rooms/lagos/ikeja/ogba/562133-boat-house-training-and-event-center">
# <div class="wp-block-img-container">
# <div class="wp-block-date-over property-visuals-mobile">
# <div class="inline">
# <i class="fal fa-video"></i>  1
# </div>
# <div>
# <i class="fal fa-camera"></i>  1
# </div>
# </div>
# <img alt="Boat House Training and Event Center, 21, Ogunnusi Road, Ogba, Ikeja, Lagos, Conference / Meeting / Training Room for Rent" class="sm-width-min-200-max-250 xs-width-min-200-max-350" itemprop="image" src="https://images.nigeriapropertycentre.com/properties/images/thumbs/562133/05e1f5601495f7-boat-house-training-and-event-center-conference-meeting-training-rooms-for-rent-ogba-ikeja-lagos.jpg" title="Boat House Training and Event Center, 21, Ogunnusi Road, Ogba, Ikeja, Lagos, Conference / Meeting / Training Room for Rent"/>
# </div>
# </a>
# <div class="text-center voffset-10 hidden property-visuals">
# <div>
# <i class="fal fa-camera"></i>  1 Photo </div>
# <div class="inline">
# <i class="fal fa-video"></i>  1 Video
# </div>
# </div>
# </div>
# <div class="clearfix visible-xs-block"></div>
# <div class="wp-block-content clearfix text-xs-left text-sm-left">
# <a href="/for-rent/event-centre-venue/conference-meeting-training-rooms/lagos/ikeja/ogba/562133-boat-house-training-and-event-center"><h4 class="content-title">Conference / meeting / training room for rent</h4></a>
# <address class="voffset-bottom-10"><strong><i class="fal fa-map-marker"></i>  21, Ogunnusi Road, Ogba, Ikeja, Lagos</strong></address>
# <div class="description hidden-xs" itemprop="description">
# <p>
# Boat halls at ogba, ikeja, lagos can be used as venues, places , centers for:training, seminars, meetings, workshops, conferences, private parties, concerts, product launching, trade promotions, weekend coaching, long term training, exhibition, classroom lecture, examination centres. location is 21, ogunnusi road former isheri aguda road, ogba, ikeja, lagos. unique with outstanding architectural designs to give your occasion an edge. facilities include fully air conditioned, free decoration, stand-by generator, car parking spaces, neat and water flowing toilets and conveniences. 10-350 guests in different halls such as captain hall, crew hall, sailor hall, marine hall and upper deck hall. affordable to meet your budget. centrally located on the major highway of ogba, omole, aguda, agidingbi, ikeja, lagos. easily accessible.meets international standard.
# to book call 0802 307 9485.
# available : projectors, magic boards, microphones, flip char...
# </p>
# <a href="/for-rent/event-centre-venue/conference-meeting-training-rooms/lagos/ikeja/ogba/562133-boat-house-training-and-event-center">More details</a>
# <br/>
# <br/>
# <i class="fal fa-calendar added-on"></i>  <span class="added-on">Added on 15 Jan 2020</span>
# </div>
# <span class="pull-sm-left">
# <span class="price" content="NGN">₦</span><span class="price" content="50000.00">50,000</span><span class="period"> per day</span> </span>
# <span class="pull-left">
# </span>
# <span class="marketed-by pull-right hidden-xs hidden-sm text-right">
# Boat Halls Event Center<br/>
# <strong>
# <i class="fal fa-phone fa-rotate-90"></i>  +2348023079485 </strong>
# </span>
# </div>
# </div>
# <div class="wp-block-footer">
# <ul class="aux-info"><li><i class="fal fa-toilet"></i><span>4</span> <span>Toilets</span></li><li><i class="fal fa-car"></i><span>120</span> <span>Parking Spaces</span></li><li class="save-favourite-button" id="fav-562133"><a data-type="showLoginMessage" href="javascript:void(0);"><i class="fal fa-heart"></i> Save</a></li></ul> </div>
# </div>
# </div>
# </div>

# %%
bs = BeautifulSoup(requests.get("https://nigeriapropertycentre.com/for-rent/commercial/offices/abuja/wuse/zone-5/638787-furnished-and-serviced-office").content)

# %%
bs.select('.table-bordered tr td')[4]
# Out:
# <td><strong>Type:</strong> Office Space</td>
